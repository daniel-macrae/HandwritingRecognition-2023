# %%
from data_management.loadDSSCharacters import aramicCharacterDataset
from data_management.datasetSplitter import datasetSplitter


dataSource = "monkbrill"
dataset = aramicCharacterDataset(folder_path=dataSource)
charcterClasses = dataset.charcterClasses

train_loader, validation_loader = datasetSplitter(dataset, batch_size=1, validation_split=0.2)

# %%
import matplotlib.pyplot as plt

imgs, targets = next(iter(train_loader))

plt.imshow(imgs[0].permute(1,2,0))
plt.title(charcterClasses[targets[0]])
plt.show()
