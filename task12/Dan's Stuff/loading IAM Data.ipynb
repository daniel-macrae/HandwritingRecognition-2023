# %% [markdown]
# ### This file shows how to load the IAM data for Task 3

# %%
from data_management.datasetSplitter import datasetSplitter
from data_management.loadIAM import IAMDataset

dataSource = "IAM-data" # name of the folder, works with "monkbrill" as well
dataset = IAMDataset(folder_path=dataSource)

train_loader, validation_loader = datasetSplitter(dataset, batch_size=1, validation_split=0.2)

# %%
import matplotlib.pyplot as plt


imgs, targets = next(iter(train_loader))

plt.imshow(imgs[0].permute(1,2,0), cmap='gray')
plt.title([targets[0]])
plt.show()
