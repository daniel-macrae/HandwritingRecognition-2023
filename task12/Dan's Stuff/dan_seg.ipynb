# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

from data_management.augmentation.commonAug import whitespaceRemover

gray_img = cv2.imread('image-data\P342-Fg001-R-C01-R01-binarized.jpg', cv2.IMREAD_GRAYSCALE)

fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize=(20,12))

gray_img = whitespaceRemover(img=gray_img, padding=20)

inv_gray_img = cv2.bitwise_not(gray_img)

ax1.imshow(inv_gray_img)
ax1.set_title("inv_gray")

#blurred = cv2.GaussianBlur(inv_gray_img, (11, 11), 0)

#_, thresholded = cv2.threshold(blurred, 0, 200, cv2.THRESH_OTSU)
#thresholded = cv2.bitwise_not(thresholded)

kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (7,3))
morph = cv2.morphologyEx(inv_gray_img, cv2.MORPH_ERODE, kernel, iterations=1)

ax2.imshow(morph)
ax2.set_title("eroded")

kernel_close = cv2.getStructuringElement(cv2.MORPH_RECT, (3,5))
morph = cv2.morphologyEx(morph, cv2.MORPH_CLOSE, kernel_close, iterations=3)


ax3.imshow(morph)
ax3.set_title("closed")

# erode 
kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (2,2))
morph = cv2.morphologyEx(morph, cv2.MORPH_ERODE, kernel, iterations=3)

#morph = cv2.GaussianBlur(morph, (5, 5), 0)
#morph = cv2.morphologyEx(morph, cv2.MORPH_ERODE, kernel, iterations=3)

kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (1,3))
morph = cv2.morphologyEx(morph, cv2.MORPH_CLOSE, kernel_close, iterations=2)


ax4.imshow(morph)
ax4.set_title("eroded")

_, thresholded = cv2.threshold(morph, 0, 255, cv2.THRESH_OTSU)

plt.show()

# %%
from skimage import morphology


gray_img = cv2.imread('image-data\P342-Fg001-R-C01-R01-binarized.jpg', cv2.IMREAD_GRAYSCALE)
gray_img = whitespaceRemover(img=gray_img, padding=20)
im = cv2.bitwise_not(gray_img)
#im = cv2.GaussianBlur(im, (21, 21), cv2.BORDER_DEFAULT)

radius = 3
fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize=(20,12))

im_open = morphology.closing(im, morphology.disk(radius))
im_recon = morphology.reconstruction(im, im_open, method='dilation')


ax1.imshow(im)
ax2.imshow(im_open)
ax3.imshow(im_recon)
ax4.imshow(im_recon - im)
plt.tight_layout()

# %%
import cv2
from data_management.augmentation.commonAug import whitespaceRemover
import time

img = cv2.imread('image-data\P342-Fg001-R-C01-R01-binarized.jpg', cv2.IMREAD_GRAYSCALE)
img = whitespaceRemover(img=img, padding=20)
img = inv_gray_img.copy()


kernel_close = cv2.getStructuringElement(cv2.MORPH_RECT, (2,2))
img = cv2.morphologyEx(img, cv2.MORPH_CLOSE, kernel_close, iterations=5)


startTime = time.time()

mser = cv2.MSER_create()
mser.setMaxArea(200000)
#mser.setMinArea(1000)

#Resize the image so that MSER can work better
img = cv2.resize(img, (img.shape[1]*2, img.shape[0]*2))


vis = cv2.cvtColor(img.copy(), cv2.COLOR_GRAY2RGB)

regions = mser.detectRegions(img)
hulls = [cv2.convexHull(p.reshape(-1, 1, 2)) for p in regions[0]]

cv2.polylines(vis, hulls, 1, (0,255,0)) 

endTime = time.time()
print(endTime - startTime)


plt.figure(figsize=(20,12))
plt.imshow(vis)
plt.show()

cv2.namedWindow('img')
cv2.imshow('img', vis)
while(cv2.waitKey()!=ord('q')):
    continue
cv2.destroyAllWindows()
# Out:
# 10.882241249084473

# %%
morph = np.array(im_recon.copy(), dtype=np.uint8)


drawing_img = cv2.cvtColor(gray_img, cv2.COLOR_GRAY2RGB)

#kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (5,5))
#morph = cv2.morphologyEx(morph, cv2.MORPH_DILATE, kernel, iterations=2)
morph = cv2.threshold(morph, 0, 255, cv2.THRESH_BINARY | cv2.THRESH_OTSU)[1]
ret, labels = cv2.connectedComponents(morph)
contours, hierarchy = cv2.findContours(morph, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
for label in range(1, ret):
    component = np.uint8(labels == label) * 255
    contours, _ = cv2.findContours(component, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)

    # filter out small or invalid bounding boxes
    for j, contour in enumerate(contours):
            (x, y, w, h) = cv2.boundingRect(contour)
            # these are artifacts
            if (w < 20 or h < 30):
                continue

            drawing_img = cv2.rectangle(drawing_img, (x,y), (x+w, y+h), color = (255,0,0), thickness=4)


fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20,12))

ax1.imshow(morph)
ax2.imshow(drawing_img)

plt.show()

# %%
from skimage.morphology import reconstruction, area_opening


gray = gray_img.copy()
#_, gray = cv2.threshold(gray, 0, 255, cv2.THRESH_OTSU)

bw_small_opened = area_opening(gray, 64, connectivity=500)
#bw_small_opened = area_opening(bw_small_opened, 50, connectivity=5)
#bw_small_opened = area_opening(bw_small_opened, 50, connectivity=5)



fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(20,30))

ax1.imshow(gray)
ax2.imshow(bw_small_opened)
ax3.imshow(bw_small_opened - gray)
plt.show()

# %%
from skimage import morphology


im = cv2.imread('image-data/P632-Fg001-R-C01-R01-binarized.jpg', cv2.IMREAD_GRAYSCALE)
im = cv2.bitwise_not(im)

im = cv2.GaussianBlur(im, (5, 5), 0)


bw_low = im > (im.mean())
bw_high = im > (im.mean() + 50)
#bw_hist = morphology.reconstruction(bw_high, bw_low)

kernel_close = cv2.getStructuringElement(cv2.MORPH_RECT, (3,3))
bw_hist = cv2.morphologyEx(im, cv2.MORPH_CLOSE, kernel_close, iterations=3)

bw_hist = np.array(bw_hist, np.uint8)

bw_hist = cv2.threshold(bw_hist, 0, 255, cv2.THRESH_BINARY | cv2.THRESH_OTSU)[1]
# erode 
#kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (2,2))
#bw_hist = cv2.morphologyEx(bw_hist, cv2.MORPH_ERODE, kernel, iterations=4)



plt.figure(figsize=(10,8))
plt.imshow(bw_hist)
plt.show()

# %%
morph = bw_hist.copy()


drawing_img = cv2.cvtColor(gray_img, cv2.COLOR_GRAY2RGB)

ret, labels = cv2.connectedComponents(thresholded)

#kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (5,5))
#morph = cv2.morphologyEx(morph, cv2.MORPH_DILATE, kernel, iterations=2)

contours, hierarchy = cv2.findContours(morph, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)


for label in range(1, ret):
    component = np.uint8(labels == label) * 255
    #component = cv2.bitwise_and(labels, label)

    
    #kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (3,3))
    #component =  cv2.dilate(component, (5,5), iterations=3)

    # filter out small or invalid bounding boxes
    for j, contour in enumerate(contours):
            (x, y, w, h) = cv2.boundingRect(contour)
            # these are artifacts
            #if (w < 20 or h < 20):
            #    continue

            #w += 20
            #h += 20

            drawing_img = cv2.rectangle(drawing_img, (x,y), (x+w, y+h), color = (255,0,0), thickness=2)


fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20,12))

ax1.imshow(morph)
ax2.imshow(drawing_img)

plt.show()

# %%
from skimage.morphology import reconstruction, area_opening


drawing_img = cv2.cvtColor(gray_img, cv2.COLOR_GRAY2RGB)

ret, labels = cv2.connectedComponents(morph)



contours, hierarchy = cv2.findContours(morph, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
for label in range(1, 5):
    component = np.uint8(labels == label) * 255


    seed = component
    mask = morph 

    y_seed = 255  * np.ones_like(mask)

    
    filled = reconstruction(y_seed, mask, method='erosion')

    plt.imshow(component)
    plt.show()
    #component = cv2.bitwise_and(labels, label)

# %%
image = inv_gray_img.copy()

seed = np.copy(image)
seed[1:-1, 1:-1] = image.max()
mask = image



_, thresholded = cv2.threshold(image, 0, 150, cv2.THRESH_OTSU)

mask = cv2.morphologyEx(thresholded, cv2.MORPH_DILATE, kernel, iterations=2)


dilated = reconstruction(seed, mask, method='dilation')


plt.imshow(dilated)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\danie\Desktop\FSE 22-23\HandwritingRecognition-2023\dan_seg.ipynb Cell 4 in 1
#       <a href='vscode-notebook-cell:/c%3A/Users/danie/Desktop/FSE%2022-23/HandwritingRecognition-2023/dan_seg.ipynb#X11sZmlsZQ%3D%3D?line=8'>9</a> _, thresholded = cv2.threshold(image, 0, 150, cv2.THRESH_OTSU)
#      <a href='vscode-notebook-cell:/c%3A/Users/danie/Desktop/FSE%2022-23/HandwritingRecognition-2023/dan_seg.ipynb#X11sZmlsZQ%3D%3D?line=10'>11</a> mask = cv2.morphologyEx(thresholded, cv2.MORPH_DILATE, kernel, iterations=2)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/danie/Desktop/FSE%2022-23/HandwritingRecognition-2023/dan_seg.ipynb#X11sZmlsZQ%3D%3D?line=13'>14</a> dilated = reconstruction(seed, mask, method='dilation')
#      <a href='vscode-notebook-cell:/c%3A/Users/danie/Desktop/FSE%2022-23/HandwritingRecognition-2023/dan_seg.ipynb#X11sZmlsZQ%3D%3D?line=16'>17</a> plt.imshow(dilated)
#
# File c:\Users\danie\miniconda3\envs\handwritingRecognition\Lib\site-packages\skimage\morphology\grayreconstruct.py:119, in reconstruction(seed, mask, method, footprint, offset)
#     117 assert tuple(seed.shape) == tuple(mask.shape)
#     118 if method == 'dilation' and np.any(seed > mask):
# --> 119     raise ValueError("Intensity of seed image must be less than that "
#     120                      "of the mask image for reconstruction by dilation.")
#     121 elif method == 'erosion' and np.any(seed < mask):
#     122     raise ValueError("Intensity of seed image must be greater than that "
#     123                      "of the mask image for reconstruction by erosion.")
#
# ValueError: Intensity of seed image must be less than that of the mask image for reconstruction by dilation.

# %%
from skimage.segmentation import (morphological_chan_vese,
                                  morphological_geodesic_active_contour,
                                  inverse_gaussian_gradient,
                                  checkerboard_level_set)

def store_evolution_in(lst):
    """Returns a callback function to store the evolution of the level sets in
    the given list.
    """

    def _store(x):
        lst.append(np.copy(x))

    return _store

#plt.imshow(thresholded)

image = gray_img

init_ls = checkerboard_level_set(image.shape, 6)


init_ls = checkerboard_level_set(image.shape, 20)

evolution = []
callback = store_evolution_in(evolution)
ls = morphological_chan_vese(image, num_iter=20, init_level_set=init_ls,
                             smoothing=0, iter_callback=callback)

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 8))
#ax = axes.flatten()

plt.imshow(image, cmap="gray")
#plt.axis_off()
plt.contour(ls, [0.5], colors='r')
plt.title("Morphological ACWE segmentation", fontsize=12)
# Out:
# Text(0.5, 1.0, 'Morphological ACWE segmentation')

# %%
gimage = inverse_gaussian_gradient(image)

# Initial level set
init_ls = np.zeros(image.shape, dtype=np.int8)
init_ls[10:-10, 10:-10] = 1
# List with intermediate results for plotting the evolution
evolution = []
callback = store_evolution_in(evolution)
lsGAC = morphological_geodesic_active_contour(gimage, num_iter=230,
                                           init_level_set=init_ls,
                                           smoothing=1, balloon=-1,
                                           threshold=0.69,
                                           iter_callback=callback)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\danie\Desktop\FSE 22-23\HandwritingRecognition-2023\seg.ipynb Cell 6 in 9
#       <a href='vscode-notebook-cell:/c%3A/Users/danie/Desktop/FSE%2022-23/HandwritingRecognition-2023/seg.ipynb#W5sZmlsZQ%3D%3D?line=6'>7</a> evolution = []
#       <a href='vscode-notebook-cell:/c%3A/Users/danie/Desktop/FSE%2022-23/HandwritingRecognition-2023/seg.ipynb#W5sZmlsZQ%3D%3D?line=7'>8</a> callback = store_evolution_in(evolution)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/danie/Desktop/FSE%2022-23/HandwritingRecognition-2023/seg.ipynb#W5sZmlsZQ%3D%3D?line=8'>9</a> ls = morphological_geodesic_active_contour(gimage, num_iter=230,
#      <a href='vscode-notebook-cell:/c%3A/Users/danie/Desktop/FSE%2022-23/HandwritingRecognition-2023/seg.ipynb#W5sZmlsZQ%3D%3D?line=9'>10</a>                                            init_level_set=init_ls,
#      <a href='vscode-notebook-cell:/c%3A/Users/danie/Desktop/FSE%2022-23/HandwritingRecognition-2023/seg.ipynb#W5sZmlsZQ%3D%3D?line=10'>11</a>                                            smoothing=1, balloon=-1,
#      <a href='vscode-notebook-cell:/c%3A/Users/danie/Desktop/FSE%2022-23/HandwritingRecognition-2023/seg.ipynb#W5sZmlsZQ%3D%3D?line=11'>12</a>                                            threshold=0.69,
#      <a href='vscode-notebook-cell:/c%3A/Users/danie/Desktop/FSE%2022-23/HandwritingRecognition-2023/seg.ipynb#W5sZmlsZQ%3D%3D?line=12'>13</a>                                            iter_callback=callback)
#
# File c:\Users\danie\miniconda3\envs\handwritingRecognition\Lib\site-packages\skimage\segmentation\morphsnakes.py:426, in morphological_geodesic_active_contour(gimage, num_iter, init_level_set, smoothing, threshold, balloon, iter_callback)
#     424 # Image attachment
#     425 aux = np.zeros_like(image)
# --> 426 du = np.gradient(u)
#     427 for el1, el2 in zip(dimage, du):
#     428     aux += el1 * el2
#
# File <__array_function__ internals>:180, in gradient(*args, **kwargs)
#
# File c:\Users\danie\miniconda3\envs\handwritingRecognition\Lib\site-packages\numpy\lib\function_base.py:1235, in gradient(f, axis, edge_order, *varargs)
#    1232 slice4[axis] = slice(2, None)
#    1234 if uniform_spacing:
# -> 1235     out[tuple(slice1)] = (f[tuple(slice4)] - f[tuple(slice2)]) / (2. * ax_dx)
#    1236 else:
#    1237     dx1 = ax_dx[0:-1]
#
# KeyboardInterrupt:

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 8))
#ax = axes.flatten()

plt.imshow(image, cmap="gray")
#plt.axis_off()
plt.contour(lsGAC, [0.5], colors='r')
plt.title("Morphological ACWE segmentation", fontsize=12)
